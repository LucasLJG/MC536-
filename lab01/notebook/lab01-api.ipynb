# %% [markdown]
# # Lab 1 - API de Acesso a Dados

# %% [markdown]
# # Tarefa 1
#
# Das fontes de dados disponíveis, tente encontrar fontes com formatos diferentes e importá-las via Python. Busque pelo menos dois formatos.

# %%
import io
import requests
import json
url = "https://servicodados.ibge.gov.br/api/v1/localidades/municipios/3509502"
js = requests.get(url).content
print(js.decode("utf-8"))
# Out:
# {"id":3509502,"nome":"Campinas","microrregiao":{"id":35032,"nome":"Campinas","mesorregiao":{"id":3507,"nome":"Campinas","UF":{"id":35,"sigla":"SP","nome":"São Paulo","regiao":{"id":3,"sigla":"SE","nome":"Sudeste"}}}},"regiao-imediata":{"id":350038,"nome":"Campinas","regiao-intermediaria":{"id":3510,"nome":"Campinas","UF":{"id":35,"sigla":"SP","nome":"São Paulo","regiao":{"id":3,"sigla":"SE","nome":"Sudeste"}}}}}

# %%
import pandas as pd
import io
import requests
url = "https://data.montreal.ca/dataset/05a9e718-6810-4e73-8bb9-5955efeb91a0/resource/7f939a08-be8a-45e1-b208-d8744dca8fc6/download/violations.csv"
data = requests.get(url).content
csv = pd.read_csv(io.StringIO(data.decode("utf-8")))
csv.head()
# Out:
#    id_poursuite  business_id      date  \
# 0          3976        15888  20161026
# 1          6760       115912  20190530
# 2          7594       117214  20200204
# 3          7229       116998  20191029
# 4          6337       112417  20181015
#
#                                          description  \
# 0  Les appareils utilisés à la préparation de la ...
# 1  Les appareils utilisés à la préparation de la ...
# 2  Les personnes affectées à la préparation des p...
# 3  Les personnes affectées à la préparation des p...
# 4  Les personnes affectées à la préparation des p...
#
#                                        adresse  date_jugement  \
# 0   1006 Boul. Saint-Laurent, Montréal, Québec       20180209
# 1  4745 Rue Jean-Talon Est, St-Léonard, Québec       20190627
# 2        5248 Ch. Queen-Mary, Montréal, Québec       20210506
# 3            1397 Av. Dollard, LaSalle, Québec       20191209
# 4      817 Rue Deslauriers, St-Laurent, Québec       20210112
#
# ...

# %% [markdown]
# # Tarefa 2
#
# ## Engenharia reversa
#
# Monte um diagramas que representem modelos dos dados que você terá acesso e como pretende associá-los. Coloque abaixo uma imagem do diagrama.

# %% [markdown]
# ![Diagrama Modelo Conceitual](../images/diagrama.png)
